# %% [markdown]
# <a href="https://colab.research.google.com/github/Serkidoko/vietnamese-presentation-asr-coach/blob/main/notebooks/finetune_phowhisper_lora_vietsuperspeech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Jul  2 12:03:40 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# If this GitHub repo is private, paste a read-only GitHub token here.
# Leave it empty if the repo is public or you uploaded the repo manually.
GITHUB_TOKEN = ""

REPO_URL = "https://github.com/Serkidoko/vietnamese-presentation-asr-coach.git"
REPO_DIR = "vietnamese-presentation-asr-coach"

import os
if GITHUB_TOKEN:
    REPO_URL = REPO_URL.replace("https://", f"https://{GITHUB_TOKEN}@")

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL}
# %cd {REPO_DIR}
# Out:
# Cloning into 'vietnamese-presentation-asr-coach'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 85 (delta 41), reused 72 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 24.81 KiB | 12.40 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# /content/vietnamese-presentation-asr-coach

# %%
# !pip install -q -U pip
# !pip install -q -r training/colab_requirements.txt
# Colab may preinstall torchao==0.10.0, which is incompatible with recent PEFT.
# This LoRA notebook does not use torchao, so removing it is the safest fix.
# !pip uninstall -y -q torchao || true
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.0 MB/s eta 0:00:00

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %%
# !python training/finetune_lora_vietsuperspeech.py \
  --train-samples 300 \
  --eval-samples 60 \
  --max-steps 400 \
  --batch-size 2 \
  --gradient-accumulation-steps 40
# Out:
# Traceback (most recent call last):
#   File "/content/vietnamese-presentation-asr-coach/training/finetune_lora_vietsuperspeech.py", line 9, in <module>
#     import evaluate
#   File "/usr/local/lib/python3.12/dist-packages/evaluate/__init__.py", line 29, in <module>
#     from .evaluation_suite import EvaluationSuite
#   File "/usr/local/lib/python3.12/dist-packages/evaluate/evaluation_suite/__init__.py", line 7, in <module>
#     from datasets import Dataset, DownloadConfig, DownloadMode, load_dataset
#   File "/usr/local/lib/python3.12/dist-packages/datasets/__init__.py", line 17, in <module>
#     from .arrow_dataset import Column, Dataset
#   File "/usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py", line 62, in <module>
#     from huggingface_hub import (
#   File "<frozen importlib._bootstrap>", line 1412, in _handle_fromlist
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py", line 1184, in __getattr__
#     submod = importlib.import_module(submod_path)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1132, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1191, in get_data
# KeyboardInterrupt
# ^C

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/asr_coach
# !cp -r training_outputs/phowhisper-vss-lora /content/drive/MyDrive/asr_coach/
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_3342/1664917810.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 get_ipython().system('mkdir -p /content/drive/MyDrive/asr_coach')
#       5 get_ipython().system('cp -r training_outputs/phowhisper-vss-lora /content/drive/MyDrive/asr_coach/')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
